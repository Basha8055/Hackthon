# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Basha\Downloads\uber_rides_data.xlsx - sample_train.csv")
df
# Out:
#          ride_id  fare_amount          pickup_datetime  pickup_longitude  \
# 0       24238194          7.5  2015-05-07 19:52:06 UTC        -73.999817
# 1       27835199          7.7  2009-07-17 20:04:56 UTC        -73.994355
# 2       44984355         12.9  2009-08-24 21:45:00 UTC        -74.005043
# 3       25894730          5.3  2009-06-26 08:22:21 UTC        -73.976124
# 4       17610152         16.0  2014-08-28 17:47:00 UTC        -73.925023
# ...          ...          ...                      ...               ...
# 199995  42598914          3.0  2012-10-28 10:49:00 UTC        -73.987042
# 199996  16382965          7.5  2014-03-14 01:09:00 UTC        -73.984722
# 199997  27804658         30.9  2009-06-29 00:42:00 UTC        -73.986017
# 199998  20259894         14.5  2015-05-20 14:56:25 UTC        -73.997124
# 199999  11951496         14.1  2010-05-15 04:08:00 UTC        -73.984395
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# ...

# %% [markdown]
# # What is the shape of given dataset?

# %%
df.shape
# Out:
# (200000, 8)

# %% [markdown]
# # Hw many integer columns(by default) are given in the dataset?
# *

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ride_id            200000 non-null  int64
#  1   fare_amount        200000 non-null  float64
#  2   pickup_datetime    200000 non-null  object
#  3   pickup_longitude   200000 non-null  float64
#  4   pickup_latitude    200000 non-null  float64
#  5   dropoff_longitude  199999 non-null  float64
#  6   dropoff_latitude   199999 non-null  float64
#  7   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 12.2+ MB

# %% [markdown]
# # How many missing values exists in 'dropoff_longitude' column?

# %%
df['dropoff_longitude'].isna().sum()
# Out:
# 1

# %% [markdown]
# # What is the data type of ' pickup_datetime' feature in your data?

# %%
df.info() #object
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ride_id            200000 non-null  int64
#  1   fare_amount        200000 non-null  float64
#  2   pickup_datetime    200000 non-null  object
#  3   pickup_longitude   200000 non-null  float64
#  4   pickup_latitude    200000 non-null  float64
#  5   dropoff_longitude  199999 non-null  float64
#  6   dropoff_latitude   199999 non-null  float64
#  7   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 12.2+ MB

# %% [markdown]
# # Which of the following is the correct syntax to convert 'pickup_datetime' to datetime datatype?

# %%
df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ride_id            200000 non-null  int64
#  1   fare_amount        200000 non-null  float64
#  2   pickup_datetime    200000 non-null  datetime64[ns, UTC]
#  3   pickup_longitude   200000 non-null  float64
#  4   pickup_latitude    200000 non-null  float64
#  5   dropoff_longitude  199999 non-null  float64
#  6   dropoff_latitude   199999 non-null  float64
#  7   passenger_count    200000 non-null  int64
# dtypes: datetime64[ns, UTC](1), float64(5), int64(2)
# memory usage: 12.2 MB

# %% [markdown]
# # Which function can be used to remove null values from the dataframe?

# %%
df=df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199999 entries, 0 to 199999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ride_id            199999 non-null  int64
#  1   fare_amount        199999 non-null  float64
#  2   pickup_datetime    199999 non-null  datetime64[ns, UTC]
#  3   pickup_longitude   199999 non-null  float64
#  4   pickup_latitude    199999 non-null  float64
#  5   dropoff_longitude  199999 non-null  float64
#  6   dropoff_latitude   199999 non-null  float64
#  7   passenger_count    199999 non-null  int64
# dtypes: datetime64[ns, UTC](1), float64(5), int64(2)
# memory usage: 13.7 MB

# %% [markdown]
# # What is the average fare amount?

# %%
df["fare_amount"].mean()
# Out:
# 11.359891549457748

# %% [markdown]
# # What is the maximum 'fare_amount' for a ride?

# %%
df["fare_amount"].max()
# Out:
# 499.0

# %%
df
# Out:
#          ride_id  fare_amount           pickup_datetime  pickup_longitude  \
# 0       24238194          7.5 2015-05-07 19:52:06+00:00        -73.999817
# 1       27835199          7.7 2009-07-17 20:04:56+00:00        -73.994355
# 2       44984355         12.9 2009-08-24 21:45:00+00:00        -74.005043
# 3       25894730          5.3 2009-06-26 08:22:21+00:00        -73.976124
# 4       17610152         16.0 2014-08-28 17:47:00+00:00        -73.925023
# ...          ...          ...                       ...               ...
# 199995  42598914          3.0 2012-10-28 10:49:00+00:00        -73.987042
# 199996  16382965          7.5 2014-03-14 01:09:00+00:00        -73.984722
# 199997  27804658         30.9 2009-06-29 00:42:00+00:00        -73.986017
# 199998  20259894         14.5 2015-05-20 14:56:25+00:00        -73.997124
# 199999  11951496         14.1 2010-05-15 04:08:00+00:00        -73.984395
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# ...

# %% [markdown]
# # How many rides were recorded in the year 2014?

# %%
df[df['pickup_datetime'].dt.year == 2014]
# Out:
#          ride_id  fare_amount           pickup_datetime  pickup_longitude  \
# 4       17610152        16.00 2014-08-28 17:47:00+00:00        -73.925023
# 6       48725865        24.50 2014-10-12 07:04:00+00:00        -73.961447
# 20      55085966        10.50 2014-02-18 14:26:00+00:00        -73.980022
# 26      38755863         5.00 2014-01-21 06:55:00+00:00        -73.957802
# 34      19277743        39.50 2014-06-04 06:49:00+00:00        -73.788080
# ...          ...          ...                       ...               ...
# 199979   9699676         6.00 2014-06-08 21:38:43+00:00        -73.975209
# 199981  21553740         9.00 2014-06-02 21:51:50+00:00        -73.980445
# 199982  13096190        57.33 2014-08-06 11:06:06+00:00        -73.969204
# 199994   3189201        12.00 2014-01-31 14:42:00+00:00        -73.983070
# 199996  16382965         7.50 2014-03-14 01:09:00+00:00        -73.984722
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# ...

# %% [markdown]
# # How many rides were recorded in the first quarter of 2014?

# %%
df[(df['pickup_datetime'].dt.year == 2014) & (df['pickup_datetime'].dt.quarter == 1)]
# Out:
#          ride_id  fare_amount           pickup_datetime  pickup_longitude  \
# 20      55085966         10.5 2014-02-18 14:26:00+00:00        -73.980022
# 26      38755863          5.0 2014-01-21 06:55:00+00:00        -73.957802
# 39      38703737         29.0 2014-02-13 17:57:00+00:00        -73.992600
# 46      37192633         17.0 2014-01-16 14:58:09+00:00        -73.993900
# 100     29350780          9.0 2014-02-19 18:02:00+00:00        -73.958280
# ...          ...          ...                       ...               ...
# 199931  28516870         11.0 2014-01-08 20:52:14+00:00        -74.005809
# 199943   9784541         10.0 2014-02-13 18:06:00+00:00        -73.970460
# 199964   4642171          6.0 2014-02-25 13:37:00+00:00        -73.991367
# 199994   3189201         12.0 2014-01-31 14:42:00+00:00        -73.983070
# 199996  16382965          7.5 2014-03-14 01:09:00+00:00        -73.984722
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# ...

# %% [markdown]
# # On which day of the week in September 2010, maximum rides were recorded ?

# %%
a=df[(df['pickup_datetime'].dt.year == 2010) & (df['pickup_datetime'].dt.month == 9)]
a['pickup_datetime'].dt.day_name().value_counts()
# Out:
# Thursday     457
# Wednesday    391
# Saturday     362
# Friday       354
# Sunday       331
# Tuesday      322
# Monday       265
# Name: pickup_datetime, dtype: int64

# %%
from math import radians, sin, cos, sqrt, atan2
def haversine_distance(lat1, lon1, lat2, lon2):
        lat1, lon1, lat2, lon2 = map(radians, [lat1, lon1, lat2, lon2])
        dlat = lat2 - lat1
        dlon = lon2 - lon1
        a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
        c = 2 * atan2(sqrt(a), sqrt(1-a))
        distance = 6371.0 * c  # Earth radius in kilometers
        return distance
        df['haversine_distance'] = df.apply(lambda row: haversine_distance(row['pickup_latitude'], row['pickup_longitude'], row['dropoff_latitude'], row['dropoff_longitude']), axis=1)

df
# Out:
#          ride_id  fare_amount           pickup_datetime  pickup_longitude  \
# 0       24238194          7.5 2015-05-07 19:52:06+00:00        -73.999817
# 1       27835199          7.7 2009-07-17 20:04:56+00:00        -73.994355
# 2       44984355         12.9 2009-08-24 21:45:00+00:00        -74.005043
# 3       25894730          5.3 2009-06-26 08:22:21+00:00        -73.976124
# 4       17610152         16.0 2014-08-28 17:47:00+00:00        -73.925023
# ...          ...          ...                       ...               ...
# 199995  42598914          3.0 2012-10-28 10:49:00+00:00        -73.987042
# 199996  16382965          7.5 2014-03-14 01:09:00+00:00        -73.984722
# 199997  27804658         30.9 2009-06-29 00:42:00+00:00        -73.986017
# 199998  20259894         14.5 2015-05-20 14:56:25+00:00        -73.997124
# 199999  11951496         14.1 2010-05-15 04:08:00+00:00        -73.984395
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# ...

# %% [markdown]
# # What is the median haversine distance between pickup and dropoff location according to the given dataset?

# %%
df["haversine_distance"].median()
# Out:
# 2.1209923961833708

# %% [markdown]
# # What is the maximum haversine distance between pickup and dropoff location according to the given dataset?

# %%
df["haversine_distance"].max()
# Out:
# 16409.239135313168

# %% [markdown]
# # How many rides have 0.0 haversine distance between pickup and dropoff location according to the given dataset?

# %%
df[df['haversine_distance'] == 0.0]
# Out:
#          ride_id  fare_amount           pickup_datetime  pickup_longitude  \
# 5       44470845          4.9 2011-02-12 02:27:09+00:00        -73.969019
# 7       44195482          2.5 2012-12-11 13:52:00+00:00          0.000000
# 11       6379048          8.5 2011-05-23 22:15:00+00:00          0.000000
# 48      22405517         56.8 2013-01-03 22:24:41+00:00        -73.993498
# 65      21993993          6.0 2014-05-05 19:27:00+00:00          0.000000
# ...          ...          ...                       ...               ...
# 199880  35013970          6.5 2014-02-22 06:45:46+00:00          0.000000
# 199883  44115598         12.5 2012-09-10 17:39:00+00:00          0.000000
# 199917  45368488          4.5 2013-06-24 22:17:43+00:00        -73.793768
# 199932  46517645         24.9 2011-03-22 13:59:00+00:00        -73.974618
# 199963  50075618         39.0 2012-09-22 07:46:01+00:00          0.000000
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# ...

# %% [markdown]
# # What is the mean 'fare_amount' for rides with 0 haversine distance?
#
# # Do you sense something fishy? Try to analyze, and give your expert opinion in Jupyter Notebook.

# %%
a=df[df['haversine_distance'] == 0.0]
a['fare_amount'].mean()
# Yes, I've observed a higher mean 'fare_amount' for rides with a Haversine distance of 0.0 compared to the typical mean.
# Out:
# 11.585317826704546

# %% [markdown]
# # What is the haversine distance between pickup and dropoff location for the costliest ride?
#
# # Do you sense something fishy? Try to analyze, and give your expert opinion in Jupyter Notebook.

# %%
df
# Out:
#          ride_id  fare_amount           pickup_datetime  pickup_longitude  \
# 0       24238194          7.5 2015-05-07 19:52:06+00:00        -73.999817
# 1       27835199          7.7 2009-07-17 20:04:56+00:00        -73.994355
# 2       44984355         12.9 2009-08-24 21:45:00+00:00        -74.005043
# 3       25894730          5.3 2009-06-26 08:22:21+00:00        -73.976124
# 4       17610152         16.0 2014-08-28 17:47:00+00:00        -73.925023
# ...          ...          ...                       ...               ...
# 199995  42598914          3.0 2012-10-28 10:49:00+00:00        -73.987042
# 199996  16382965          7.5 2014-03-14 01:09:00+00:00        -73.984722
# 199997  27804658         30.9 2009-06-29 00:42:00+00:00        -73.986017
# 199998  20259894         14.5 2015-05-20 14:56:25+00:00        -73.997124
# 199999  11951496         14.1 2010-05-15 04:08:00+00:00        -73.984395
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# ...

# %%
costliest_ride = df[df['fare_amount'] == df['fare_amount'].max()]
costliest_ride 
# yes, haversine_distance is 0.00079 this not fair the for the costliest_ride 
# Here max haversine_distance 16409.239135 and this fair amont is 15.7 this will not be match to analysis the dateframe exactly.
# Out:
#          ride_id  fare_amount           pickup_datetime  pickup_longitude  \
# 170081  51151143        499.0 2011-04-10 04:10:00+00:00        -73.968377
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 170081        40.764602         -73.968368           40.7646                1
#
#         haversine_distance
# 170081             0.00079

# %%
df[df['haversine_distance'] == df['haversine_distance'].max()]
# Out:
#         ride_id  fare_amount           pickup_datetime  pickup_longitude  \
# 75851  33249845         15.7 2011-11-05 00:22:00+00:00       -1340.64841
#
#        pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 75851      1644.421482         -3356.6663        872.697628                1
#
#        haversine_distance
# 75851        16409.239135
